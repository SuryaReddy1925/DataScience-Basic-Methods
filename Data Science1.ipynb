# %%
import numpy as np
a=np.array([12,34,35,56])
a
# Out:
# array([12, 34, 35, 56])

# %%
b=np.array([[1,2,3],
            [2,5,6]
            ])
b
# Out:
# array([[1, 2, 3],
#        [2, 5, 6]])

# %%
a.shape
# Out:
# (4,)

# %%
b.shape
# Out:
# (2, 3)

# %%
a.ndim
# Out:
# 1

# %%
b.ndim
# Out:
# 2

# %%
a.dtype
# Out:
# dtype('int64')

# %%
b.dtype
# Out:
# dtype('int64')

# %%
c=np.arange(6)
c
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
d=np.arange(1,15,3)
d
# Out:
# array([ 1,  4,  7, 10, 13])

# %%
a=np.array([2,3,4,5])
b=np.array([3,4,5,6])

# %%
a+b
# Out:
# array([ 5,  7,  9, 11])

# %%
a-b
# Out:
# array([-1, -1, -1, -1])

# %%
a*b
# Out:
# array([ 6, 12, 20, 30])

# %%
a/b
# Out:
# array([0.66666667, 0.75      , 0.8       , 0.83333333])

# %%
a=np.array([0,1,1,0],dtype=bool)
b=np.array([1,1,1,0],dtype=bool)

# %%
a
# Out:
# array([False,  True,  True, False])

# %%
a
# Out:
# array([False,  True,  True, False])

# %%
np.logical_or(a,b)
# Out:
# array([ True,  True,  True, False])

# %%
np.logical_and(a,b)
# Out:
# array([False,  True,  True, False])

# %%
a=np.arange(4)
a
# Out:
# array([0, 1, 2, 3])

# %%
np.sin(a)
# Out:
# array([0.        , 0.84147098, 0.90929743, 0.14112001])

# %%
np.log(a)
# Out:
# <ipython-input-28-89b6b8e53c58>:1: RuntimeWarning: divide by zero encountered in log
#   np.log(a)
# array([      -inf, 0.        , 0.69314718, 1.09861229])

# %%
np.exp(a)
# Out:
# array([ 1.        ,  2.71828183,  7.3890561 , 20.08553692])

# %%
a=np.array([0,5,6,7])
a
# Out:
# array([0, 5, 6, 7])

# %%
np.sum(a)
# Out:
# 18

# %%
a=np.array([[1,2,3,4],[5,6,7,8]])
a
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
np.sum(a,axis=1)
# Out:
# array([10, 26])

# %%
np.sum(a,axis=0)
# Out:
# array([ 6,  8, 10, 12])

# %%
np.max(a)
# Out:
# 8

# %%
np.min(a)
# Out:
# 1

# %%
np.argmax(a)
# Out:
# 7

# %%
np.argmin(a)
# Out:
# 0

# %%
a=np.array([1,2,3,4,5,6,7])

# %%
np.mean(a)
# Out:
# 4.5

# %%
np.median(a)
# Out:
# 4.5

# %%
np.std(a)
# Out:
# 2.29128784747792

# %%
a=np.array([[1.0,2.0],[3.0,4.0]])
a
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
np.linalg.inv(a)
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
a@a
# Out:
# array([[ 7., 10.],
#        [15., 22.]])

# %%
a.dot(a)
# Out:
# array([[ 7., 10.],
#        [15., 22.]])

# %%
np.linalg.eig(a)
# Out:
# (array([-0.37228132,  5.37228132]),
#  array([[-0.82456484, -0.41597356],
#         [ 0.56576746, -0.90937671]]))

# %%
import pandas as pd
d=pd.DataFrame({'A':[1,3,2],
                'B':['AA','BB','CC']})
print(d)
c=pd.DataFrame(d,columns=['B','A'],index=['X','Y','Z'])
print(c)
# Out:
#    A   B
# 0  1  AA
# 1  3  BB
# 2  2  CC
#      B   A
# X  NaN NaN
# Y  NaN NaN
# Z  NaN NaN

# %%
import numpy as np
import pandas as pd
obj=pd.Series(['c','a','d','a','a','b','b','c','c'])
obj
# Out:
# 0    c
# 1    a
# 2    d
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
obj.unique()
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
obj.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
obj.notnull()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# dtype: bool

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import randn
df=pd.DataFrame(np.random.randn(10,4).cumsum(0),columns=['A','B','C','D'],index=np.arange(0,100,10))
df.plot()
plt.show()

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(6,4),index=['one','two','three','four','five','six'],columns=pd.Index(['A','B','C','D'],name='Genus'))
df
# Out:
# Genus         A         B         C         D
# one    0.973853  0.286604  0.271059  0.887100
# two    0.427792  0.831916  0.714193  0.651690
# three  0.800814  0.945932  0.086159  0.610902
# four   0.328262  0.200149  0.846705  0.151748
# five   0.339801  0.754030  0.481231  0.382683
# six    0.232098  0.845641  0.467327  0.847287

# %%
import matplotlib.pyplot as plt
import pandas as pd
df1=pd.DataFrame({'key':['b','b','a','c','a','a','b'],
                  'data1':range(7)})
df2=pd.DataFrame({'key':['a','b','d'],
                  'data2':range(3)})
print(df1)
print(df2)
print(pd.merge(df1,df2))
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6
#   key  data2
# 0   a      0
# 1   b      1
# 2   d      2
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
print(pd.merge(df1,df2,how='inner'))
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
print(pd.merge(df1,df2,how='outer'))
# Out:
#   key  data1  data2
# 0   b    0.0    1.0
# 1   b    1.0    1.0
# 2   b    6.0    1.0
# 3   a    2.0    0.0
# 4   a    4.0    0.0
# 5   a    5.0    0.0
# 6   c    3.0    NaN
# 7   d    NaN    2.0

# %%
print(pd.merge(df1,df2,how='left'))
# Out:
#   key  data1  data2
# 0   b      0    1.0
# 1   b      1    1.0
# 2   a      2    0.0
# 3   c      3    NaN
# 4   a      4    0.0
# 5   a      5    0.0
# 6   b      6    1.0

# %%
print(pd.merge(df1,df2,how='right'))
# Out:
#   key  data1  data2
# 0   a    2.0      0
# 1   a    4.0      0
# 2   a    5.0      0
# 3   b    0.0      1
# 4   b    1.0      1
# 5   b    6.0      1
# 6   d    NaN      2

# %%
import pandas as pd
left=pd.DataFrame({'key1':['foo','foo','bar'],
                   'key2':['one','two','one'],
                   'lval':[1,2,3]})
right=pd.DataFrame({'key1':['foo','foo','bar','bar'],
                    'key2':['one','one','one','two'],
                    'rval':[4,5,6,7]})
print(pd.merge(left,right,on=['key1','key2'],how='outer'))
# Out:
#   key1 key2  lval  rval
# 0  foo  one   1.0   4.0
# 1  foo  one   1.0   5.0
# 2  foo  two   2.0   NaN
# 3  bar  one   3.0   6.0
# 4  bar  two   NaN   7.0

# %%
pd.merge(left,right,on='key1')
# Out:
#   key1 key2_x  lval key2_y  rval
# 0  foo    one     1    one     4
# 1  foo    one     1    one     5
# 2  foo    two     2    one     4
# 3  foo    two     2    one     5
# 4  bar    one     3    one     6
# 5  bar    one     3    two     7

# %%
import pandas as pd
left1=pd.DataFrame({'key':['a','b','a','a','b','c'],
                    'value':range(6)})
right1=pd.DataFrame({'group_val': [3.5, 7]}, index=['a', 'b'])
print(left1)
print(right1)
# Out:
#   key  value
# 0   a      0
# 1   b      1
# 2   a      2
# 3   a      3
# 4   b      4
# 5   c      5
#    group_val
# a        3.5
# b        7.0

# %%
 pd.merge(left1, right1, left_on='key', right_index=True)
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 2   a      2        3.5
# 3   a      3        3.5
# 1   b      1        7.0
# 4   b      4        7.0

# %%
 pd.merge(left1, right1, left_on='key', right_index=True, how='outer')
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 2   a      2        3.5
# 3   a      3        3.5
# 1   b      1        7.0
# 4   b      4        7.0
# 5   c      5        NaN

# %%
import pandas as pd
arr=np.arange(12).reshape((3,4))
arr

# %%
import numpy as np
np.concatenate([arr,arr],axis=1)
# Out:
# array([[ 0,  1,  2,  3,  0,  1,  2,  3],
#        [ 4,  5,  6,  7,  4,  5,  6,  7],
#        [ 8,  9, 10, 11,  8,  9, 10, 11]])

# %%
s1 = pd.Series([0, 1], index=['a', 'b'])
s2 = pd.Series([2, 3, 4], index=['c', 'd', 'e'])
s3 = pd.Series([5, 6], index=['f', 'g'])
pd.concat([s1,s2,s3])
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# dtype: int64

# %%
pd.concat([s1,s2,s3],axis=1)
# Out:
#      0    1    2
# a  0.0  NaN  NaN
# b  1.0  NaN  NaN
# c  NaN  2.0  NaN
# d  NaN  3.0  NaN
# e  NaN  4.0  NaN
# f  NaN  NaN  5.0
# g  NaN  NaN  6.0

# %%
s4 = pd.concat([s1 * 5, s3])
pd.concat([s1, s4], axis=1)
# Out:
#      0  1
# a  0.0  0
# b  1.0  5
# f  NaN  5
# g  NaN  6

# %%
pd.concat([s1, s4], axis=1, join='inner')
# Out:
#    0  1
# a  0  0
# b  1  5

# %%
 pd.concat([s1, s4], axis=1)
# Out:
#      0  1
# a  0.0  0
# b  1.0  5
# f  NaN  5
# g  NaN  6

# %%
import pandas as pd
data=pd.DataFrame([['AG','IS','ML&DL','ML&DL','DS','SFE','LIB'],
                   ['BCT','AG','LIB','SFE','DS','DS','SFE'],
                   ['DS','BCT','IS','LIB','SFE','SFE','LIB'],
                   ['DS','AG','BCT','BCT','ML&DL LAB','ML&DL LAB','ML&DL LAB'],
                   ['SFE','LIB','ML&DL','ML&DL','IS','IS','AG'],
                   ['BCT','ML&DL','IS','AG','SPORTS','SPORTS','SPORTS']],
                  index=['MON','TUE','WED','THUR','FRI','SAT'],
                  columns=[1,2,3,4,5,6,7])
data
# Out:
#         1      2      3      4          5          6          7
# MON    AG     IS  ML&DL  ML&DL         DS        SFE        LIB
# TUE   BCT     AG    LIB    SFE         DS         DS        SFE
# WED    DS    BCT     IS    LIB        SFE        SFE        LIB
# THUR   DS     AG    BCT    BCT  ML&DL LAB  ML&DL LAB  ML&DL LAB
# FRI   SFE    LIB  ML&DL  ML&DL         IS         IS         AG
# SAT   BCT  ML&DL     IS     AG     SPORTS     SPORTS     SPORTS

# %%
data=pd.DataFrame({'k1': ['one'] * 3 + ['two'] * 4,
   'k2': [1, 1, 2, 3, 3, 4, 4]})
data
# Out:
#     k1  k2
# 0  one   1
# 1  one   1
# 2  one   2
# 3  two   3
# 4  two   3
# 5  two   4
# 6  two   4

# %%
data.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 2  one   2
# 3  two   3
# 5  two   4

# %%
data.drop_duplicates(['k1'])
# Out:
#     k1  k2
# 0  one   1
# 3  two   3

# %%
data.drop_duplicates(['k1','k2'])
# Out:
#     k1  k2
# 0  one   1
# 2  one   2
# 3  two   3
# 5  two   4

# %%
data['v1']=range(7)
data
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  one   1   1
# 2  one   2   2
# 3  two   3   3
# 4  two   3   4
# 5  two   4   5
# 6  two   4   6

# %%
data=pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon', 'Pastrami',
        'corned beef', 'Bacon', 'pastrami', 'honey ham',
        'nova lox'],
        'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {
 'bacon': 'pig',
 'pulled pork': 'pig',
 'pastrami': 'cow',
 'corned beef': 'cow',
 'honey ham': 'pig',
 'nova lox': 'salmon'
}

# %%
data['animal'] = data['food'].map(str.lower).map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
data['food'].map(lambda x: meat_to_animal[x.lower()])
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
data=pd.Series([1., -999., 2., -999., -1000., 3.])
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace(-999, np.nan)
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace([-999, -1000], np.nan)
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace([-999, -1000], [np.nan, 0])
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
 data.replace({-999: np.nan, -1000: 0})
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(1000,4))
df
# Out:
#             0         1         2         3
# 0   -0.972731 -0.912841  0.957953 -0.277961
# 1    0.741092 -1.470561 -0.685545 -1.494861
# 2    0.291735 -0.590598 -0.451246 -1.261986
# 3    0.146300  0.980532  0.227627  0.469072
# 4    0.538519  1.299338  0.976166 -0.197875
# ..        ...       ...       ...       ...
# 995  0.271691 -0.164621  0.582088 -0.239480
# 996  1.216396  1.657448  0.344340 -0.145563
# 997 -0.711020 -1.021352  0.728215 -0.453169
# 998  0.983155 -0.230875  0.180757  0.623465
# 999 -0.545237  0.816226 -0.206961 -0.380494
#
# [1000 rows x 4 columns]

# %%
df.describe()
# Out:
#                  0            1            2            3
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.024455     0.018542     0.010319     0.004211
# std       1.001817     1.045498     0.946216     1.015790
# min      -2.884147    -4.098814    -2.834086    -3.217729
# 25%      -0.692287    -0.706000    -0.584145    -0.707396
# 50%       0.054483     0.008424    -0.000504     0.005713
# 75%       0.704741     0.746009     0.614566     0.659397
# max       2.875013     3.265548     2.969321     3.239881

# %%
from datetime import datetime
now=datetime.now()
now
# Out:
# datetime.datetime(2023, 10, 11, 11, 53, 29, 760810)

# %%
now.day,now.month,now.year
# Out:
# (11, 10, 2023)
